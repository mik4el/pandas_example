# %% [markdown]
# # Setting up

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
MONDAY_KEY = os.getenv("MONDAY_KEY")
import requests

def run_query(query): # A simple function to use requests.post to make the API call. Note the json= section.
    request = requests.post('https://api.monday.com/v2', json={'query': query}, headers=headers)
    if request.status_code == 200:
        return request.json()
    else:
        raise Exception("Query failed to run by returning code of {}. {}".format(request.status_code, query))

headers = {"Authorization":MONDAY_KEY}

# %% [markdown]
# # Who owns most boards?

# %%
query = """
{
  boards(limit:1000) {
      id 
      name
    	owner {
        name
      }
    }
}
"""        
result = run_query(query)
print(result["data"])
# Out:
# {'boards': [{'id': '117607607', 'name': 'Software update requests', 'owner': {'name': 'Alper Aydemir'}}, {'id': '118277986', 'name': 'Brand and creative backlog', 'owner': {'name': 'julia.krantz@volumental.com'}}, {'id': '119285058', 'name': 'Alper', 'owner': {'name': 'Alper Aydemir'}}, {'id': '119522493', 'name': 'Old Scanner sales', 'owner': {'name': 'henrik.bronnegard@volumental.com'}}, {'id': '119941922', 'name': 'Product - Retail Scanner', 'owner': {'name': 'Alper Aydemir'}}, {'id': '119941959', 'name': 'Product - Vaka', 'owner': {'name': 'Alper Aydemir'}}, {'id': '119942028', 'name': 'Product - Omni', 'owner': {'name': 'Alper Aydemir'}}, {'id': '120056215', 'name': 'External product deadlines', 'owner': {'name': 'Alper Aydemir'}}, {'id': '120793385', 'name': 'Major ideation projects', 'owner': {'name': 'Alper Aydemir'}}, {'id': '120820357', 'name': 'Infrastructure / DevOps', 'owner': {'name': 'Alper Aydemir'}}, {'id': '121222983', 'name': 'Operations', 'owner': {'name': 'Jon Duvnjak'}}, {'id': '121665338', 'name': 'Lead - XXL/Brunngård', 'owner': {'name': 'Alper Aydemir'}}, {'id': '122061023', 'name': 'Samuel', 'owner': {'name': 'Samuel Carlsson'}}, {'id': '122429601', 'name': 'Jon', 'owner': {'name': 'Jon Duvnjak'}}, {'id': '122432432', 'name': 'Legal/commercial', 'owner': {'name': 'Jon Duvnjak'}}, {'id': '122452892', 'name': 'Metrics / Data Science', 'owner': {'name': 'Josef Grahn'}}, {'id': '122861494', 'name': 'Internal scanner requests', 'owner': {'name': 'Jon Duvnjak'}}, {'id': '122864226', 'name': 'Pilot requests', 'owner': {'name': 'Jon Duvnjak'}}, {'id': '123223812', 'name': 'Roadmap Q3 2018', 'owner': {'name': 'Ingrid Bonde Åkerlind'}}, {'id': '123307088', 'name': 'Board of Directors', 'owner': {'name': 'Alper Aydemir'}}, {'id': '123669092', 'name': 'Sofie', 'owner': {'name': 'Sofie Berglykke Aagaard'}}, {'id': '123698934', 'name': 'Footwear Research', 'owner': {'name': 'ales.jurca@volumental.com'}}, {'id': '123931901', 'name': 'Mik4el', 'owner': {'name': 'Mikael Andersson'}}, {'id': '124173144', 'name': 'Strategy Topics', 'owner': {'name': 'moritz.schiebold@volumental.com'}}, {'id': '124179300', 'name': 'Council', 'owner': {'name': 'moritz.schiebold@volumental.com'}}, {'id': '124705830', 'name': 'Volumental Office', 'owner': {'name': 'julia.krantz@volumental.com'}}, {'id': '126202176', 'name': "Customer - The Athlete's Foot", 'owner': {'name': 'Jon Duvnjak'}}, {'id': '126377360', 'name': 'Copy & Design', 'owner': {'name': 'Ingrid Bonde Åkerlind'}}, {'id': '126767799', 'name': 'P&C - Ongoing Deliveries & Backlog', 'owner': {'name': 'Mariana Puhlmann'}}, {'id': '127112174', 'name': 'Returns investigation', 'owner': {'name': 'Alper Aydemir'}}, {'id': '127505567', 'name': 'Lead - Sales Flow', 'owner': {'name': 'Eric Abrahamsson'}}, {'id': '127583684', 'name': 'ML reading group', 'owner': {'name': 'Josef Grahn'}}, {'id': '127966600', 'name': 'Lead - Deichmann/One FID', 'owner': {'name': 'Dan Engelke'}}, {'id': '128377298', 'name': 'Weekly Planning - Karthik', 'owner': {'name': 'Karthik Parupalli'}}, {'id': '129056675', 'name': 'Lead - Myer', 'owner': {'name': 'Eric Abrahamsson'}}, {'id': '129096693', 'name': 'Sales Process', 'owner': {'name': 'Alper Aydemir'}}, {'id': '129484698', 'name': 'Customer - New Balance', 'owner': {'name': 'Mark Hughes'}}, {'id': '129485964', 'name': 'Customer - Wintersteiger', 'owner': {'name': 'Mark Hughes'}}, {'id': '129486432', 'name': 'Customer - Fleet Feet', 'owner': {'name': 'Mark Hughes'}}, {'id': '129488407', 'name': 'Customer - Bauer', 'owner': {'name': 'Mark Hughes'}}, {'id': '129905150', 'name': "Josef's high-level roadmap", 'owner': {'name': 'Josef Grahn'}}, {'id': '130407831', 'name': 'US Customer Trip - October/November 2018', 'owner': {'name': 'Mark Hughes'}}, {'id': '131022600', 'name': 'P&C - Onboarding Checklist', 'owner': {'name': 'Mariana Puhlmann'}}, {'id': '131889071', 'name': 'Lead - Treksta', 'owner': {'name': 'Eric Abrahamsson'}}, {'id': '132765382', 'name': 'Lead ...

# %%
import pandas as pd
df = pd.DataFrame.from_dict(result["data"]["boards"])

# %%
df.dtypes
# Out:
# id       object
# name     object
# owner    object
# dtype: object

# %%
df
# Out:
#             id                                               name  \
# 0    117607607                           Software update requests
# 1    118277986                         Brand and creative backlog
# 2    119285058                                              Alper
# 3    119522493                                  Old Scanner sales
# 4    119941922                           Product - Retail Scanner
# ..         ...                                                ...
# 139  320717717   4 Paying Tgd Mkg Customers April 2020 Goal Board
# 140  320748494                         Open questions KAM / Lukas
# 141  320870710      User Testing internship - Recruitment Roadmap
# 142  320873285  Swedish scanners assemblers - Recruitment Roadmap
# 143  325494501                                      Customer Days
#
#                                             owner
# 0                       {'name': 'Alper Aydemir'}
# 1         {'name': 'julia.krantz@volumental.com'}
# 2                       {'name': 'Alper Aydemir'}
# 3    {'name': 'henrik.bronnegard@volumental.com'}
# 4                       {'name': 'Alper Aydemir'}
# ..                                            ...
# 139             {'name': 'Ingrid Bonde Åkerlind'}
# 140                  {'name': 'Yohan Braoudakis'}
# 141                  {'name': 'Mariana Puhlmann'}
# 142                  {'name': 'Mariana Puhlmann'}
# 143                     {'name': 'Alice Wristel'}
#
# [144 rows x 3 columns]

# %%
df.owner
# Out:
# 0                         {'name': 'Alper Aydemir'}
# 1           {'name': 'julia.krantz@volumental.com'}
# 2                         {'name': 'Alper Aydemir'}
# 3      {'name': 'henrik.bronnegard@volumental.com'}
# 4                         {'name': 'Alper Aydemir'}
#                            ...
# 139               {'name': 'Ingrid Bonde Åkerlind'}
# 140                    {'name': 'Yohan Braoudakis'}
# 141                    {'name': 'Mariana Puhlmann'}
# 142                    {'name': 'Mariana Puhlmann'}
# 143                       {'name': 'Alice Wristel'}
# Name: owner, Length: 144, dtype: object

# %%
from pandas.io.json import json_normalize
df.owner = json_normalize(df["owner"], meta=["name"])

# %%
df
# Out:
#             id                                               name  \
# 0    117607607                           Software update requests
# 1    118277986                         Brand and creative backlog
# 2    119285058                                              Alper
# 3    119522493                                  Old Scanner sales
# 4    119941922                           Product - Retail Scanner
# ..         ...                                                ...
# 139  320717717   4 Paying Tgd Mkg Customers April 2020 Goal Board
# 140  320748494                         Open questions KAM / Lukas
# 141  320870710      User Testing internship - Recruitment Roadmap
# 142  320873285  Swedish scanners assemblers - Recruitment Roadmap
# 143  325494501                                      Customer Days
#
#                                 owner
# 0                       Alper Aydemir
# 1         julia.krantz@volumental.com
# 2                       Alper Aydemir
# 3    henrik.bronnegard@volumental.com
# 4                       Alper Aydemir
# ..                                ...
# 139             Ingrid Bonde Åkerlind
# 140                  Yohan Braoudakis
# 141                  Mariana Puhlmann
# 142                  Mariana Puhlmann
# 143                     Alice Wristel
#
# [144 rows x 3 columns]

# %%
df["count"] = 1

# %%
toplist = df.groupby(['owner']).count().sort_values("count", ascending=True)['count']

# %%
from matplotlib import pyplot as plt
toplist_plot = toplist.plot(kind='barh', figsize=(10, 10), width=0.7)
toplist_plot.set_ylabel("Owner")
toplist_plot.set_xlabel("Boards owned")
# Out:
# Text(0.5, 0, 'Boards owned')

# %% [markdown]
# # How many updates have we made?

# %%
query = """
{
    updates(limit:10000) {
    	created_at
    	creator {
        name
      }
    }
}
"""
result = run_query(query)
print(result["data"])
updates_df = pd.DataFrame.from_dict(result["data"]["updates"])
# Out:
# {'updates': [{'created_at': '2019-09-19T08:46:11Z', 'creator': {'name': 'marc.armgren@volumental.com'}}, {'created_at': '2019-09-18T19:22:26Z', 'creator': {'name': 'Mark Hughes'}}, {'created_at': '2019-09-18T18:24:29Z', 'creator': {'name': 'miroslav.kobetski@volumental.com'}}, {'created_at': '2019-09-18T15:33:02Z', 'creator': {'name': 'Eveline Visee'}}, {'created_at': '2019-09-18T15:28:52Z', 'creator': {'name': 'Mariana Puhlmann'}}, {'created_at': '2019-09-18T15:02:56Z', 'creator': {'name': 'Hanyue Zhou'}}, {'created_at': '2019-09-18T14:10:44Z', 'creator': {'name': 'Silvia Scalisi'}}, {'created_at': '2019-09-18T14:00:34Z', 'creator': {'name': 'Akanksha Srivastava'}}, {'created_at': '2019-09-18T14:00:19Z', 'creator': {'name': 'Christian Adåker'}}, {'created_at': '2019-09-18T13:42:53Z', 'creator': {'name': 'miroslav.kobetski@volumental.com'}}, {'created_at': '2019-09-18T13:25:55Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-18T13:25:38Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-18T13:10:44Z', 'creator': {'name': 'Eveline Visee'}}, {'created_at': '2019-09-18T13:05:45Z', 'creator': {'name': 'Alper Aydemir'}}, {'created_at': '2019-09-18T12:53:36Z', 'creator': {'name': 'Dan Engelke'}}, {'created_at': '2019-09-18T12:51:29Z', 'creator': {'name': 'Eveline Visee'}}, {'created_at': '2019-09-18T12:49:27Z', 'creator': {'name': 'Dan Engelke'}}, {'created_at': '2019-09-18T12:48:23Z', 'creator': {'name': 'Dan Engelke'}}, {'created_at': '2019-09-18T12:29:07Z', 'creator': {'name': 'Christian Adåker'}}, {'created_at': '2019-09-18T10:59:58Z', 'creator': {'name': 'Eveline Visee'}}, {'created_at': '2019-09-18T09:37:40Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-18T09:28:16Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-18T07:23:57Z', 'creator': {'name': 'julia.krantz@volumental.com'}}, {'created_at': '2019-09-17T14:05:16Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T13:59:24Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T13:06:29Z', 'creator': {'name': 'Christian Adåker'}}, {'created_at': '2019-09-17T13:05:46Z', 'creator': {'name': 'Mariana Puhlmann'}}, {'created_at': '2019-09-17T13:03:29Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:52:55Z', 'creator': {'name': 'moritz.schiebold@volumental.com'}}, {'created_at': '2019-09-17T12:39:54Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:38:56Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:34:52Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:24:12Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:11:47Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:10:18Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:02:54Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T12:01:31Z', 'creator': {'name': 'Alice Wristel'}}, {'created_at': '2019-09-17T11:48:11Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T11:37:06Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T11:30:19Z', 'creator': {'name': 'henrik.bronnegard@volumental.com'}}, {'created_at': '2019-09-17T11:04:44Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T10:33:56Z', 'creator': {'name': 'Oskar Lilja'}}, {'created_at': '2019-09-17T10:09:10Z', 'creator': {'name': 'Mikael Andersson'}}, {'created_at': '2019-09-17T09:09:32Z', 'creator': {'name': 'Akanksha Srivastava'}}, {'created_at': '2019-09-17T09:06:29Z', 'creator': {'name': 'Karthik Parupalli'}}, {'created_at': '2019-09-17T08:44:12Z', 'creator': {'name': 'Mark Hughes'}}, {'created_at': '2019-09-17T08:43:28Z', 'creator': {'name': 'Mark Hughes'}}, {'created_at': '2019-09-17T08:40:28Z', 'creator': {'name': 'Mark Hughes'}}, {'created_at': '2019-09-17T08:09:29Z', 'creator': {'name': 'Akanksha Srivastava'}}, {'created_at ...

# %%
updates_df.head()
# Out:
#              created_at                                       creator
# 0  2019-09-19T08:46:11Z       {'name': 'marc.armgren@volumental.com'}
# 1  2019-09-18T19:22:26Z                       {'name': 'Mark Hughes'}
# 2  2019-09-18T18:24:29Z  {'name': 'miroslav.kobetski@volumental.com'}
# 3  2019-09-18T15:33:02Z                     {'name': 'Eveline Visee'}
# 4  2019-09-18T15:28:52Z                  {'name': 'Mariana Puhlmann'}

# %%
updates_df.creator = json_normalize(updates_df["creator"], meta=["name"])

# %%
updates_df["created_at"] = (pd.to_datetime(updates_df.created_at, infer_datetime_format=True))
updates_df.sort_values("created_at", ascending=True)
# Out:
#               created_at                           creator
# 6904 2018-08-09 11:33:51                     Alper Aydemir
# 6903 2018-08-09 12:45:20                     Alper Aydemir
# 6902 2018-08-10 08:45:32                     Alper Aydemir
# 6901 2018-08-10 11:03:44      lukas.tallund@volumental.com
# 6900 2018-08-13 09:30:06                     Alper Aydemir
# ...                  ...                               ...
# 4    2019-09-18 15:28:52                  Mariana Puhlmann
# 3    2019-09-18 15:33:02                     Eveline Visee
# 2    2019-09-18 18:24:29  miroslav.kobetski@volumental.com
# 1    2019-09-18 19:22:26                       Mark Hughes
# 0    2019-09-19 08:46:11       marc.armgren@volumental.com
#
# [6905 rows x 2 columns]

# %%
updates_df["total_updates"] = updates_df.index
updates_df["total_updates"] = updates_df.created_at.count() - updates_df["total_updates"]

# %%
updates_df_plot = updates_df.plot(x="created_at", y="total_updates")
updates_df_plot.set_ylabel("Total updates")
updates_df_plot.set_xlabel("Time")
# Out:
# Text(0.5, 0, 'Time')

# %% [markdown]
# # Who makes the most updates?

# %%
updates_df["count"] = 1
top_updaters = updates_df.groupby(['creator']).count().sort_values("count", ascending=True)['count']

# %%
top_updaters
# Out:
# creator
# Vince Wols                            1
# Lana Kaupuza                          1
# openspace@volumental.com              2
# Therese Harborn                       2
# Madhuri Joshi                         4
# Christian Adåker                      5
# marc.armgren@volumental.com           6
# Corinna Karg                          6
# Nikolaus West                        11
# Alice Wristel                        12
# Rebecca Nelson                       16
# Sofie Berglykke Aagaard              17
# Boa Jung                             19
# Courtney Thomas                      22
# Sara Andersson                       25
# ales.jurca@volumental.com            28
# Deniz Akkaya                         31
# Karthik Parupalli                    33
# Yohan Braoudakis                     37
# Aina Rosselló                        37
# Oskar Lilja                          52
# Dan Engelke                          53
# Liz Connor                           53
# julia.krantz@volumental.com          53
# Vic Yu                               73
# Silvia Scalisi                       75
# Eric Abrahamsson                     77
# Rasmus                               79
# Caroline Walerud                     80
# Anna Malkan                          86
# Niklas Karlsson                      87
# Sajith                               93
# Hanyue Zhou                         103
# Samuel Carlsson                     109
# Kristina Jurca                      112
# moritz.schiebold@volumental.com     114
# Akanksha Srivastava                 121
# axel demborg                        123
# miroslav.kobetski@volumental.com    123
# Ke Wang                             129
# Josef Grahn                         160
# Kamil Macinski                      167
# henrik.bronnegard@volumental.com    173
# magnus.burenius@volumental.com      179
# Mariana Puhlmann                    194
# Ingrid Bonde Åkerlind               248
# lukas.tallund@volumental.com        300
# Eveline Visee                       392
# leila.ljungberg@volumental.com      400
# Jon Duvnjak                         535
# Alper Aydemir                       539
# Mark Hughes                         568
# Mikael Andersson                    940
# Name: count, dtype: int64

# %%
top_updaters_plot = top_updaters.plot(kind='barh', figsize=(10, 10), width=0.7)
top_updaters_plot.set_ylabel("Creator")
top_updaters_plot.set_xlabel("Updates created")
# Out:
# Text(0.5, 0, 'Updates created')
